# %%
#!pip install tabula-py
#!pip install googlemaps
#!pip install beautifulsoup4
#!pip install wayback-machine-scraper
#!pip install xlwt

# %%
import requests
from urllib.parse import urljoin
from urllib.request import urlretrieve
from pathlib import Path
from bs4 import BeautifulSoup
import glob
import pandas as pd
import re
import googlemaps
import tabula
import os

# %%
def extract_links_from_webarchive_snapshots(folder: str, tag_name, class_value):
    hrefs = []
    for file in glob.glob(f"{folder}*.snapshot"):
        links = BeautifulSoup(open(file)).find_all(tag_name, {'class': class_value})
        if links:
            if len(links)> 1:
                ignored_links = [l.a['href'] for l in links[1:]]
                print(f"Ignored links: {ignored_links}")
            l = links[0].a['href']
            hrefs.append(l)
    return hrefs

# %%
def extract_auctions_from_aler_website(url, output_dir, class_name, BASE_URL = "https://alermipianovendite.it"):
   
    
    r = requests.get(url)
    html = r.text
    elements = BeautifulSoup(html).find_all("td", {"class": class_name})
    for el in elements:
        href = el.a.get('href')
        complete_href = urlretrieve(urljoin(BASE_URL, href), filename = f'{output_dir}/{href.split("/")[-1]}')
        print(f"Downloaded {complete_href}")

# %%
def extract_dataframe_from_pdf(pdf_folder):
    
    columns_10 = ['LOTTO', 'CODICE', 'BOX/P.A.', 'LOCALITA', 'INDIRIZZO', 'CIVICO', 'ID', 'PREZZO BASE', 'PREZZO_AG', 'AGGIUDICATARIO']
    columns_9 =  ['LOTTO', 'CODICE', 'LOCALITA', 'INDIRIZZO', 'CIVICO', 'ID', 'PREZZO BASE', 'PREZZO_AG', 'AGGIUDICATARIO']
    columns_9_2020 =['LOTTO', 'CODICE', 'BOX/P.A.', 'LOCALITA', 'INDIRIZZO', 'CIVICO', 'PREZZO BASE', 'PREZZO_AG', 'AGGIUDICATARIO']
    columns_8 =  ['LOTTO', 'CODICE', 'LOCALITA', 'INDIRIZZO', 'CIVICO', 'PREZZO BASE', 'PREZZO_AG', 'AGGIUDICATARIO']
    dfs = []
    
    
    for file in Path(pdf_folder).glob("*.pdf"):
        print(f"Analyzing {file}")

        match = re.search(r'(\d+)([a-z]+)(\d+)', str(file))
        giorno, mese, anno = match.groups()


        tables = tabula.read_pdf(file, pages = "all", multiple_tables = True, pandas_options={'header': None})

        for table in tables:
            if table.shape[1] == 8:
                table.columns = columns_8
                #tabula is unable to split the last two columns, due few space between columns
                if file.stem == 'esito-18febbraio15':
                    table[['PREZZO_AG', 'AGGIUDICATARIO']] = table['AGGIUDICATARIO'].str.split(",00", expand=True)
            elif table.shape[1] == 9: 
                #remove header from the table
                if file.stem == 'esito-24settembre2020':
                    table = table.iloc[1:]
                    table.reset_index(inplace=True, drop=True)

                if (table.loc[0,4].startswith('VIA')) | (table.loc[0,4].startswith('PIAZZA')):
                    table.columns = columns_9_2020
                elif (table.loc[0,3].startswith('VIA')) | (table.loc[0,3].startswith('PIAZZA')):
                    table.columns = columns_9
                else:
                    raise Exception("ERRORE")

            elif table.shape[1] == 10:
                table.columns = columns_10
            else:
                print(table.shape)
            table['GIORNO'] = giorno
            table['MESE'] = mese
            table['ANNO'] = anno
            dfs.append(table)

    data = pd.concat(dfs, axis=0, ignore_index=True) 
    return data

# %%
def geocode(address_series: pd.Series, api_key:str):
    gmaps = googlemaps.Client(key=api_key)
    addresses = []

    series_unique = address_series.unique()
    print(f"Analyzing {len(series_unique)} addresses")
    for address in series_unique:
        print(address)
        geocode_result = gmaps.geocode(address)
        location = geocode_result[0]['geometry']['location']
        addresses.append({
            'address': address,
            'lat': location['lat'],
            'lng':  location['lng']
        })
    return pd.DataFrame(addresses)

# %%
def extract_dataframe_from_webpage(urls):
    
    set_url = set()
    dfs = []
    
    for url in urls:
        auction = list(filter(None, url.split("/")))[-1]
        
        if auction not in set_url:
            print(f"Extracting df about auction {auction}")
            try:
                htables = pd.read_html(url, header=0)
                df = None
                for t in htables:
                    if "LOTTO" in t.columns:
                        df = t
                        break
                if df is None:    
                    print(f"WARNING url {url} doesn't contains data")
                else:    
                    dfs.append(df)
                
                set_url.add(auction)
                
            except Exception as e:
                print(f"Error analyzing url {url}. Error {e}")
    
    return dfs

# %%
def normalize_dfs(list_df, columns):
    dfs_filtred = []
    n_max = len(columns)
    
    for df in list_df:
        df = df[df.columns[0:n_max]]
        df.columns = columns
        dfs_filtred.append(df)


    return pd.concat(dfs_filtred)

# %% [markdown]
# ## Estrazione esiti aste

# %%
# !mkdir -p ./auction_data

# %%
BASE_URL = "https://alermipianovendite.it"
auction_dir = "./auction_data"

#2020-2022
extract_auctions_from_aler_website(url=f"{BASE_URL}/esiti-piano-vendite-2020-2022/",
                                   output_dir=auction_dir,
                                   class_name="column-2")

#to 2020
extract_auctions_from_aler_website(url=f"{BASE_URL}/esiti-piano-vendite-2014-2019/",
                                   output_dir=auction_dir,
                                   class_name="column-1")
# Out:
# Downloaded ('./auction_data/esito-18febbraio2021.pdf', <http.client.HTTPMessage object at 0x12313c3d0>)
# Downloaded ('./auction_data/esito-21gennaio2021.pdf', <http.client.HTTPMessage object at 0x12313c390>)
# Downloaded ('./auction_data/esito-17dicembre2020.pdf', <http.client.HTTPMessage object at 0x12313c810>)
# Downloaded ('./auction_data/esito-19novembre2020.pdf', <http.client.HTTPMessage object at 0x12313cbd0>)
# Downloaded ('./auction_data/esito-22ottobre2020.pdf', <http.client.HTTPMessage object at 0x12313c450>)
# Downloaded ('./auction_data/esito-24settembre2020.pdf', <http.client.HTTPMessage object at 0x12313c7d0>)
# Downloaded ('./auction_data/esito-21luglio2020.pdf', <http.client.HTTPMessage object at 0x12313cb90>)
# Downloaded ('./auction_data/esito-05dicembre19.pdf', <http.client.HTTPMessage object at 0x123151b50>)
# Downloaded ('./auction_data/esito-24ottobre19.pdf', <http.client.HTTPMessage object at 0x123151650>)
# Downloaded ('./auction_data/esito-26settembre19.pdf', <http.client.HTTPMessage object at 0x123151350>)
# Downloaded ('./auction_data/esito-25luglio19.pdf', <http.client.HTTPMessage object at 0x123151f90>)
# Downloaded ('./auction_data/esito-27giugno19.pdf', <http.client.HTTPMessage object at 0x123151c90>)
# Downloaded ('./auction_data/esito-23maggio19.pdf', <http.client.HTTPMessage object at 0x123151650>)
# Downloaded ('./auction_data/esito-18aprile19.pdf', <http.client.HTTPMessage object at 0x123151510>)
# Downloaded ('./auction_data/esito-21marzo19.pdf', <http.client.HTTPMessage object at 0x1231517d0>)
# Downloaded ('./auction_data/esito-21febbraio19.pdf', <http.client.HTTPMessage object at 0x123151d10>)
# Downloaded ('./auction_data/esito-17gennaio19.pdf', <http.client.HTTPMessage object at 0x123151d50>)
# Downloaded ('./auction_data/esito-29novembre18.pdf', <http.client.HTTPMessage object at 0x1231513d0>)
# Downloaded ('./auction_data/esito-31ottobre18.pdf', <http.client.HTTPMessage object at 0x123151e50>)
# Downloaded ('./auction_data/esito-27settembre18.pdf', <http.client.HTTPMessage object at 0x123151d50>)
# Downloaded ('./auction_data/esito-26luglio18.pdf', <http.client.HTTPMessage object at 0x123151d10>)
# Downloaded ('./auction_data/esito-28giugno18.pdf', <http.client.HTTPMessage object at 0x1231513d0>)
# Downloaded ('./auction_data/esito-24maggio18.pdf', <http.client.HTTPMessage object at 0x123151690>)
# Downloaded ('./auction_data/esito-12aprile18.pdf', <http.client.HTTPMessage object at 0x123151b90>)
# Downloaded ('./auction_data/esito-08marzo18.pdf', <http.client.HTTPMessage object at 0x123151750>)
# Downloaded ('./auction_data/esito-01febbraio18.pdf', <http.client.HTTPMessage object at 0x123151910>)
# Downloaded ('./auction_data/esito-14dicembre17.pdf', <http.client.HTTPMessage object at 0x123151790>)
# Downloaded ('./auction_data/esito-10novembre17.pdf', <http.client.HTTPMessage object at 0x123151990>)
# Downloaded ('./auction_data/esito-05ottobre17.pdf', <http.client.HTTPMessage object at 0x123151490>)
# Downloaded ('./auction_data/esito-06luglio17.pdf', <http.client.HTTPMessage object at 0x123151690>)
# Downloaded ('./auction_data/esito-25maggio17.pdf', <http.client.HTTPMessage object at 0x123151c50>)
# Downloaded ('./auction_data/esito-12aprile17.pdf', <http.client.HTTPMessage object at 0x123151a90>)
# Downloaded ('./auction_data/esito-08marzo17.pdf', <http.client.HTTPMessage object at 0x123151950>)
# Downloaded ('./auction_data/esito-31gennaio17.pdf', <http.client.HTTPMessage object at 0x123151750>)
# Downloaded ('./auction_data/esito-24novembre16.pdf', <http.client.HTTPMessage object at 0x123151fd0>)
# Downloaded ('./auction_data/esito-06ottobre16.pdf', <http.client.HTTPMessage object at 0x123151790>)
# Downloaded ('./auction_data/esito-30giugno16.pdf', <http.client.HTTPMessage object at 0x1231513d0>)
# Downloaded ('./auction_data/esito-30maggio16.pdf', <http.client.HTTPMessage object at 0x1231517d0>)
# Downloaded ('./auction_data/esito-21aprile16.pdf', <http.client.HTTPMessage object at 0x123151350>)
# Downloaded ('./auction_data/esito-17marzo16.pdf', <http.client.HTTPMessage object at 0x123151690>)
# Downloaded ('./auction_data/esito-11febbraio16.pdf', <http.client.HTTPMessage object at 0x123151590>)
# Downloaded ('./auction_data/esito-15dicembre15.pdf', <http.client.HTTPMessage object at 0x123151dd0>)
# Downloaded ('./auction_data/esito-04novembre15.pdf', <http.client.HTTPMessage object at 0x123151610>)
AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Mar 16, 2021 11:36:25 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")
#     LOTTO  CODICE LOCALITA                INDIRIZZO CIVICO   ID  PREZZO BASE  \
# 0  252/15   20148   MILANO            VIA MAC MAHON    '89  NaN  € 93.139,00
# 1  253/15  230196   MILANO           VIA BRAMANTINO     '3  NaN  € 80.784,00
# 2  254/15  230657   MILANO  VIA JACOPINO DA TRADATE    '14  NaN  € 67.478,00
#
#       PREZZO_AG     AGGIUDICATARIO GIORNO     MESE ANNO BOX/P.A.
# 0  € 116.000,00  ROLLERI FRANCESCO     01  ottobre   15      NaN
# 1        € 0,00       ASTA DESERTA     01  ottobre   15      NaN
# 2   € 68.500,00    BUGARIU LILIANA     01  ottobre   15      NaN

# %%
data.shape
# Out:
# (2124, 13)

# %% [markdown]
# ## Geocoding Apartments

# %%
data['address'] = data['INDIRIZZO'] + " " + data['CIVICO'] + ", " + data['LOCALITA']
data.head(3)
# Out:
#     LOTTO  CODICE LOCALITA                INDIRIZZO CIVICO   ID  PREZZO BASE  \
# 0  252/15   20148   MILANO            VIA MAC MAHON    '89  NaN  € 93.139,00
# 1  253/15  230196   MILANO           VIA BRAMANTINO     '3  NaN  € 80.784,00
# 2  254/15  230657   MILANO  VIA JACOPINO DA TRADATE    '14  NaN  € 67.478,00
#
#       PREZZO_AG     AGGIUDICATARIO GIORNO     MESE ANNO BOX/P.A.  \
# 0  € 116.000,00  ROLLERI FRANCESCO     01  ottobre   15      NaN
# 1        € 0,00       ASTA DESERTA     01  ottobre   15      NaN
# 2   € 68.500,00    BUGARIU LILIANA     01  ottobre   15      NaN
#
#                                address
# 0            VIA MAC MAHON '89, MILANO
# 1            VIA BRAMANTINO '3, MILANO
# 2  VIA JACOPINO DA TRADATE '14, MILANO

# %%
api_key = "AIzaSyBdCWCLzV83HuTHJYFOzXyd8RlJI6pWNig"

df_addresses = geocode(data['address'], api_key=api_key)
# Out:
# Analyzing 730 addresses
# VIA MAC MAHON '89, MILANO
# VIA BRAMANTINO '3, MILANO
# VIA JACOPINO DA TRADATE '14, MILANO
# VIA GASPARE ASELLI '18, MILANO
# VIA FILIPPO ABBIATI '5, MILANO
# VIA DALMAZIO BIRAGO '2, MILANO
# VIA DALMAZIO BIRAGO '4, MILANO
# VIA ANGELO INGANNI '52, MILANO
# VIA COMASINA '57, MILANO
# VIA TEANO '36, MILANO
# VIA SANTUARIO DEL SACRO CUORE '3, MILANO
# VIALE UNGHERIA '2, MILANO
# VIA LUIGI SORDELLO '10, MILANO
# VIA CONCILIO VATICANO II '10, MILANO
# VIA DEGLI ONTANI '44, MILANO
# VIA DEI SALICI '59, MILANO
# VIA COSTANTINO BARONI '75, MILANO
# VIA ALESSANDRO LITTA MODIGNANI '113, MILANO
# VIA ALESSANDRO LITTA MODIGNANI '103, MILANO
# VIA ALESSANDRO LITTA MODIGNANI '115, MILANO
# VIA FILIPPO DE PISIS '27, MILANO
# VIA GIACOMO QUARENGHI '43, MILANO
# VIALE ITALIA '34, CORSICO
# VIA MARZABOTTO '20, CORSICO
# VIA BENVENUTO CELLINI '12, CORSICO
# VIA AGOSTINO DE PRETIS '51, MILANO
# VIA ENRICO DE NICOLA '8, MILANO
# VIALE LAZIO '21, ROZZANO
# VIALE LAZIO '76, ROZZANO
# VIA DEGLI ANEMONI '3, MILANO
# VIA GIUSEPPE ROVANI '311, SESTO SAN GIOVANNI
# VIA FRATELLI BANDIERA '200, SESTO SAN GIOVANNI
# VIA MODENA '2, SESTO SAN GIOVANNI
# VIA PADRE REGINALDO GIULIANI '40, LEGNANO
# VIA BRENNERO '6, LEGNANO
# VIA SAN GIROLAMO EMILIANI '16, MAGENTA
# VIALE JOHN FITZGERALD KENNEDY '45, NERVIANO
# VIA CASCINA CORBA '98, MILANO
# VIA DEI TIGLI '12, GORGONZOLA
# VIA ANTONIO GRAMSCI '51, RHO
# VIA AURORA '12, PADERNO DUGNANO
# VIA TICINO '8, GARBAGNATE MILANE
# VIA CAMILLO GIUSSANI '20, MILANO
# VIA PATERNO' '13, MILANO
# VIA LUCCA '58, MILANO
# VIA LUCCA '46, MILANO
# VIA BOLOGNA '15, CANEGRATE
# VIA GALILEO GALILEI '49, PIOLTELLO
# VIA DESSIE' '15, MILANO
# VIA VAL LAGARINA '34, MILANO
# VIA TRENTO '23, CORBETTA
# VIA GIOVANNI PASCOLI '2, MILANO
# VIA GIOVANNI AMBROGIO DE PREDIS '7, MILANO
# VIA GIULIO BELINZAGHI '6, MILANO
# PIAZZALE SELINUNTE '11, MILANO
# VIA LORENTEGGIO '203, MILANO
# PIAZZA CARDINALE PIETRO GASPARRI '4, MILANO
# VIA GIACOMO QUARENGHI '34, MILANO
# VIA DEI SALICI '79, MILANO
# VIA DEI SALICI '25, CESANO BOSCONE
# VIA COSTANTINO BARONI '238, MILANO
# VIA COSTANTINO BARONI '79, MILANO
# VIA FIORDALISI '1, ROZZANO
# VIA FIORDALISI '3, ROZZANO
# VIA ALESSANDRO LITTA MODIGNANI '93, MILANO
# VIA ALESSANDRO LITTA MODIGNANI '111, MILANO
# VIA APPENNINI '71, MILANO
# VIA EUGENIO CURIEL '12, CORSICO
# VIA MARZABOTTO '10, CORSICO
# VIA ENRICO DE NICOLA '24, MILANO
# VIA AGOSTINO DE PRETIS '11, MILANO
# VIA AGOSTINO DE PRETIS '99, MILANO
# VIA AGOSTINO DE PRETIS '59, MILANO
# VIALE LAZIO '19, ROZZANO
# VIALE LAZIO '24, ROZZANO
# VIA DELLE GENZIANE '3, MILANO
# VIA ADOLFO OMODEO '23/2, MILANO
# VIA ANGELO MORO '27.D, SAN DONATO MILANE
# VIA RAFFAELLO GIOLLI '23, MILANO
# VIA OSTENO '4, MILANO
# VIA URUGUAY '32, MILANO
# VIA JACOPINO DA TRADATE '8, MILANO
# VIA MEDEGHINO '24, MILANO
# VIA ORBETELLO '2, MILANO
# VIA ESCULAPIO '4, MILANO
# VIA ROMUALDO BONFADINI '98, MILANO
# VIA CONCILIO VATICANO II '4, MILANO
# VIA DEI LARICI '36, MILANO
# VIA COSTANTINO BARONI '236, MILANO
# VIA MICHELE SAPONARO '38, MILANO
# VIA LILLA' '1, ROZZANO
# VIA UGO BETTI '163, MILANO
# VIA ARTURO GRAF '56, MILANO
# VIA APPENNINI '69, MILANO
# VIA EUGENIO CURIEL '6, CORSICO
# VIA EUGENIO CURIEL '40, CORSICO
# VIA EUGENIO CURIEL '38, CORSICO
# VIA MARZABOTTO '26, CORSICO
# VIA ENRICO DE NICOLA '32, MILANO
# VIA AGOSTINO DE PRETIS '109, MILANO
# VIA AGOSTINO DE PRETIS '77, MILANO
# VIA GIUSEPPE ROVANI '317, SESTO SAN GIOVANNI
# VIA GUGLIELMO MARCONI '29, BINASCO
# VIA CATANIA '40, SESTO SAN GIOVANNI
# VIA CATANIA '50, SESTO SAN GIOVANNI
# VIA ALDO MORO '11, RHO
# VIA BELTRAME CRISTIANI '21, MILANO
# VIA CAMILLO GIUSSANI '17, MILANO
# VIA PATERNO' '7, MILANO
# VIA VAL LAGARINA '87, MILANO
# VIA SAVONA '80, SESTO SAN GIOVANNI
# VIA GIOVANNI PASCOLI '4, MILANO
# VIALE ARGONNE '35, MILANO
# VIA ORBETELLO '4, MILANO
# VIA VAL SABBIA '6, MILANO
# VIALE UNGHERIA '48, MILANO
# VIALE UNGHERIA '4, MILANO
# VIA DEGLI ONTANI '48, MILANO
# VIA DEI SALICI '55, MILANO
# VIA DEI SALICI '8, MILANO
# VIA DEI SALICI '10, MILANO
# VIA MICHELE SAPONARO '20, MILANO
# VIA MICHELE SAPONARO '24, MILANO
# VIA BETULLE '4, ROZZANO
# VIA LILLA' '3, ROZZANO
# VIA BIANCOSPINI '14, ROZZANO
# VIA ALESSANDRO LITTA MODIGNANI '107, MILANO
# VIA ARTURO GRAF '38, MILANO
# VIA FILIPPO DE PISIS '29, MILANO
# VIA APPENNINI '37, MILANO
# VIA FRANCESCO CILEA '126, MILANO
# VIA EUGENIO CURIEL '25, CORSICO
# VIA AGOSTINO DE PRETIS '57, MILANO
# VIA GIUSEPPE ROVANI '309, SESTO SAN GIOVANNI
# VIA LONGARONE '16, MILANO
# VIA FORLI' '74, SESTO SAN GIOVANNI
# VIA DEL PARCO '15, GORGONZOLA
# VIA RAFFAELLO GIOLLI '24, MILANO
# VIA CAMILLO GIUSSANI '29, MILANO
# VIA PATERNO' '14, MILANO
# VIA PATERNO' '10, MILANO
# VIA GIUSEPPE DI VITTORIO '19.H, LOCATE DI TRIULZI
# VIA VAL MALENCO '2, MILANO
# VIA ILLIRICO '1, MILANO
# VIA ORESTE SALOMONE '91, MILANO
# VIA DEGLI ONTANI '30, MILANO
# VIA ALESSANDRO LITTA MODIGNANI '109, MILANO
# VIA ARTURO GRAF '24, MILANO
# VIA ARTURO GRAF '32, MILANO
# VIA ARTURO GRAF '36, MILANO
# VIA ARTURO GRAF '44, MILANO
# VIA ARTURO GRAF '60, MILANO
# VIA APPENNINI '1, MILANO
# VIA ENRICO FALCK '41, MILANO
# VIA FRANCESCO CILEA '44, MILANO
# VIA APPENNINI '43, MILANO
# VIA FRANCESCO CILEA '154, MILANO
# VIA AGOSTINO DE PRETIS '105, MILANO
# VIA ENRICO DE NICOLA '14, MILANO
# VIA AGOSTINO DE PRETIS '29, MILANO
# VIA AGOSTINO DE PRETIS '41, MILANO
# VIA LEONARDO DA VINCI '37, CASSANO D'ADDA
# VIA MARZABOTTO '2, CORSICO
# VIA AGOSTINO DE PRETIS '83, MILANO
# VIA AGOSTINO DE PRETIS '23, MILANO
# VIA AGOSTINO DE PRETIS '37, MILANO
# VIA AGOSTINO DE PRETIS '43, MILANO
# VIALE LAZIO '15, ROZZANO
# VIALE LAZIO '23, ROZZANO
# VIALE LAZIO '26, ROZZANO
# VIALE LAZIO '50, ROZZANO
# VIALE LAZIO '88, ROZZANO
# VIA GIUSEPPE DI VITTORIO '12/D, TREZZANO SUL NAVIG
# VIA GIUSEPPE RIPAMONTI '36, MILANO
# VIA DEGLI ONTANI '38, MILANO
# VIA DEI SALICI '29, MILANO
# VIA ALESSANDRO LITTA MODIGNANI '101, MILANO
# VIA FRANCESCO CILEA '92, MILANO
# VIA FRANCESCO CILEA '60, MILANO
# VIA PIAVE '40, CESATE
# VIA DELLE GENZIANE '5, MILANO
# VIA BOLOGNA '35, MELZO
# VIA CARLO MARX '3, MILANO
# VIA LUCCA '6, MILANO
# VIA VITERBO '47, MILANO
# VIA FELICE MARITANO '12.B, SAN DONATO MILANE
# VIA G. A. DE PREDIS '11, MILANO
# VIA DEGLI ONTANI '16, MILANO
# VIA DEI LARICI '21, MILANO
# VIA UGO OJETTI '38, MILANO
# VIA ARTURO GRAF '18, MILANO
# VIA CARLO MARX '8, MILANO
# VIA TICINO '8, GARBAGNATE MIL.
# VIA CAMILLO GIUSSANI '32, MILANO
# VIA RICCARDO BALSAMO CRIVELLI '16, MILANO
# VIA DANIELE RICCIARELLI '16, MILANO
# VIA DEI SALICI '73, MILANO
# VIA DEI SALICI '15, CESANO BOSCONE
# VIA COSTANTINO BARONI '234, MILANO
# VIA COSTANTINO BARONI '256, MILANO
# VIA FIORDALISI '5, ROZZANO
# VIA ARTURO GRAF '26, MILANO
# VIA ARTURO GRAF '62, MILANO
# VIA FRANCESCO CILEA '58, MILANO
# VIA FRANCESCO CILEA '160, MILANO
# VIA AGOSTINO DE PRETIS '71, MILANO
# VIA CAMILLO GIUSSANI '15, MILANO
# VIA RICCARDO BALSAMO CRIVELLI '20, MILANO
# VIA PATERNO' '9, MILANO
# VIA FELICE MARITANO '14.A, SAN DONATO MILANE
# VIA DEI LARICI '33, MILANO
# VIA UGO BETTI '15, MILANO
# VIA UGO BETTI '69, MILANO
# VIA AGOSTINO DE PRETIS '113, MILANO
# VIA DELLE CAMELIE '6, MILANO
# VIA GIUSEPPE BOLOGNA '28, BRESSO
# VIA NICOLO' BARABINO '3, MILANO
# VIA DEGLI ABETI '7, MILANO
# VIA DEGLI ABETI '13, MILANO
# VIA UGO OJETTI '40, MILANO
# VIA UGO OJETTI '10, MILANO
# VIA UGO OJETTI '1, MILANO
# VIA FRANCESCO CILEA '26, MILANO
# VIA APPENNINI '47, MILANO
# VIA AGOSTINO DE PRETIS '31, MILANO
# VIA PADRE SECCHI '135, LEGNANO
# VIA JAN SIBELIUS '30, MILANO
# VIA PATERNO' '6, MILANO
# VIA ANTONIO CECHOV '47, MILANO
# VIA UGO BETTI '20, MILANO
# VIA UGO BETTI '28, MILANO
# VIA UGO BETTI '42, MILANO
# VIA UGO BETTI '113, MILANO
# VIA UGO OJETTI '8, MILANO
# VIA ENRICO FALCK '27, MILANO
# VIA FRANCESCO CILEA '8, MILANO
# VIA APPENNINI '75, MILANO
# VIA GIACINTO GIGANTE '5, MILANO
# VIA UGO BETTI '145, MILANO
# VIA FILIPPO DE PISIS '17, MILANO
# VIA GIOVANNI PASCOLI '10, PREGNANA MILANESE
# VIA JAN SIBELIUS '4, MILANO
# VIA PATERNO' '12, MILANO
# VIA LUIGI CHIARELLI '2, MILANO
# VIA APPENNINI '23, MILANO
# VIA APPENNINI '9, MILANO
# VIA AGOSTINO DE PRETIS '61, MILANO
# VIA AGOSTINO DE PRETIS '89, MILANO
# VIA JAN SIBELIUS '28, MILANO
# VIA RICCARDO BALSAMO CRIVELLI '22, MILANO
# VIA GASPARE ASELLI '6, MILANO
# VIA GASPARE ASELLI '10, MILANO
# VIA UGO OJETTI '9, MILANO
# VIA MARZABOTTO '22, CORSICO
# VIA ISONZO '24, CUSANO MILANINO
# VIA SANT'AMBROGIO '3, CASTANO PRIMO
# VIA ENRICO MATTEI '52, GORGONZOLA
# VIA POSTUMIA '26, MILANO
# VIA VITERBO '27, MILANO
# VIA UGO BETTI '65, MILANO
# VIA FILIPPO DE PISIS '31, MILANO
# VIA EUGENIO CURIEL '11, CORSICO
# VIA EUGENIO CURIEL '5, CORSICO
# VIA ALEX VISCONTI '17, MILANO
# VIA LONGARONE '8, MILANO
# VIA BELTRAME CRISTIANI '9, MILANO
# VIA JAN SIBELIUS '24, MILANO
# VIALE PALMIRO TOGLIATTI '17.A, LOCATE DI TRIULZI
# VIA FELICE ORSINI '70, MILANO
# VIA COSTANTINO BARONI '230, MILANO
# VIA APPENNINI '19, MILANO
# VIA APPENNINI '3, MILANO
# VIA APPENNINI '67, MILANO
# VIA ENRICO DE NICOLA '16, MILANO
# VIA VAL LAGARINA '42, MILANO
# VIA DOMENICO CUCCHIARI '12, MILANO
# VIA GIACOMO QUARENGHI '8, MILANO
# VIA FRANCESCO CILEA '130, MILANO
# VIA CARLO AMORETTI '15, MILANO
# VIA LONGARONE '33, MILANO
# VIA POSTUMIA '24, MILANO
# VIA CARLO MARX '12, MILANO
# VIA JACOPINO DA TRADATE '7, MILANO
# VIA DELLA CAPINERA '5, MILANO
# VIA DEGLI ONTANI '24, MILANO
# VIA DEGLI ONTANI '32, MILANO
# VIA UGO BETTI '67, MILANO
# VIA CLAUDIO TREVES '34, TREZZANO SUL NAVIG
# VIALE GIOVANNI SUZZANI '280, MILANO
# VIA CAMILLO GIUSSANI '1, MILANO
# VIA CAMILLO GIUSSANI '28, MILANO
# VIA PATERNO' '19, MILANO
# VIA VITERBO '39, MILANO
# VIA MARIO MORGANTINI '3, MILANO
# VIA COSTANTINO BARONI '254, MILANO
# VIA FRANCESCO CILEA '142, MILANO
# VIA AGOSTINO DE PRETIS '39, MILANO
# VIA GABRIO CASATI '5, LEGNANO
# VIA ISONZO '22, CUSANO MILANINO
# VIA RAFFAELLO GIOLLI '19, MILANO
# VIA CHIARI '7, MILANO
# VIA DEI SALICI '15, MILANO
# VIA ENRICO FALCK '23, MILANO
# VIA ADOLFO OMODEO '21, MILANO
# VIA CARLO MARX '34, MILANO
# VIA TICINO '8, GARBAGNATE M.SE
# VIA CAMILLO GIUSSANI '25, MILANO
# VIA PAOLO MASPERO '51, MILANO
# VIA FRANCESCO CILEA '30, MILANO
# VIA FRANCESCO CILEA '54, MILANO
# VIA BENVENUTO CELLINI '30, CORSICO
# VIA ENRICO DE NICOLA '28, MILANO
# VIA AGOSTINO DE PRETIS '111, MILANO
# VIA CASCINA CORBA '96, MILANO
# VIA CAMILLO GIUSSANI '21, MILANO
# VIA FILIPPO JUVARA '12, MILANO
# VIA FRANCESCO CILEA '156, MILANO
# VIA EUGENIO CURIEL '42, CORSICO
# VIA URUGUAY '15, MILANO
# VIA FRANCESCO CILEA '28, MILANO
# VIA FRANCESCO CILEA '50, MILANO
# VIA RAFFAELLO GIOLLI '28, MILANO
# VIA LUCCA '22, MILANO
# VIA LUCCA '52, MILANO

# %%
data2 = pd.merge(data, df_addresses, how="inner", on="address")
data2.to_excel("./auction_data.xls", index=False)
data2.head(2)
# Out:
# /Users/lanottef/miniconda3/envs/aler/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#     LOTTO CODICE LOCALITA      INDIRIZZO CIVICO   ID  PREZZO BASE  \
# 0  252/15  20148   MILANO  VIA MAC MAHON    '89  NaN  € 93.139,00
# 1  112/16  20134   MILANO  VIA MAC MAHON    '89  NaN  € 75.840,00
#
#       PREZZO_AG     AGGIUDICATARIO GIORNO     MESE ANNO BOX/P.A.  \
# 0  € 116.000,00  ROLLERI FRANCESCO     01  ottobre   15      NaN
# 1   € 79.150,00      NICOSIA PAOLO     21   aprile   16      NaN
#
#                      address        lat       lng
# 0  VIA MAC MAHON '89, MILANO  45.494911  9.156308
# 1  VIA MAC MAHON '89, MILANO  45.494911  9.156308

# %%
#data2[(~data2['AGGIUDICATARIO'].isna()) & (data2['AGGIUDICATARIO'].str.startswith("€"))]

# %%
#data2[(data2['GIORNO']=='18') & (data2['MESE']=='febbraio')][:30]

# %% [markdown]
# ## Scraping Web Archive
#
# Now that we have data about house auction, we need data about the apartment (e.g. size, floor, etc.)

# %%
import os
starting_url = "https://alermipianovendite.it/asta-alloggi/"
starting_url_2015 = "http://www.alermipianovendite.it/vendite/venditeasta/"
#dal 2017
os.system("wayback-machine-scraper -a 'alermipianovendite.it/asta-alloggi$' alermipianovendite.it/asta-alloggi")
#dal 2015 al 2016
os.system(" wayback-machine-scraper -a 'www.alermipianovendite.it/vendite/venditeasta' www.alermipianovendite.it/vendite/venditeasta.html")
# Out:
# 0

# %% [markdown]
# Now we have to analyze web pages extracted in the previous cell. In particular, we must:
#
#     - identifying the href link in the web page related to the storical auction
#     - open the extracted url and extract the dataframe containing dara

# %%
links_1 = extract_links_from_webarchive_snapshots(folder = "./website/alermipianovendite.it/asta-alloggi/",
                            tag_name = "article",
                            class_value = "category-asteceal"
                           )
len(links_1)
# Out:
# Ignored links: ['https://web.archive.org/web/20200924044539/https://alermipianovendite.it/asta-alloggi-24-settembre-2020/']
# 22

# %%
links_2 = extract_links_from_webarchive_snapshots(folder = "./website/www.alermipianovendite.it/vendite/venditeasta.html/",
                            tag_name = "div",
                            class_value = "globalnews"
                           )
complete_links_2 = ["https://web.archive.org" + l for l in links_2]
len(complete_links_2)
# Out:
# Ignored links: ['/web/20160503020251/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/150-esito-ceal-alloggi-apr-2016.html']
# Ignored links: ['/web/20160416233327/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/145-esito-ceal-alloggi-mar-2016.html']
# Ignored links: ['/web/20150512061812/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/106-esito-ceal-alloggi-apr-2015.html']
# Ignored links: ['/web/20150310234605/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/98-esito-ceal-alloggi-feb-2015.html']
# Ignored links: ['/web/20150612074732/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/113-esito-ceal-alloggi-mag-2015.html']
# Ignored links: ['/web/20160218111358/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/141-esito-ceal-alloggi-feb-2016.html']
# Ignored links: ['/web/20160118112617/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/134-esito-ceal-alloggi-dic-2015.html']
# Ignored links: ['/web/20150915042032/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/118-esito-ceal-alloggi-lug-2015.html']
# Ignored links: ['/web/20151012012941/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/123-esito-ceal-alloggi-ott-2015.html']
# Ignored links: ['/web/20160917081543/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/154-esito-ceal-alloggi-giu-2016.html']
# Ignored links: ['/web/20151212210306/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/128-esito-ceal-alloggi-nov-2015.html']
# Ignored links: ['/web/20160618190636/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/153-esito-ceal-alloggi-mag-2016.html']
# Ignored links: ['/web/20160518064758/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/150-esito-ceal-alloggi-apr-2016.html']
# Ignored links: ['/web/20160317024451/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/141-esito-ceal-alloggi-feb-2016.html']
# 22

# %%
dfs_1 = extract_dataframe_from_webpage(links_1)
# Out:
# Extracting df about auction asta-alloggi-24-maggio-2018
# Extracting df about auction asta-alloggi-22-ottobre-2020
# Extracting df about auction asta-alloggi-21-gennaio-2021
# Extracting df about auction asta-alloggi-14-dicembre-2017
# Extracting df about auction asta-alloggi-24-novembre-2016
# Extracting df about auction asta-alloggi-12-aprile-2018
# Extracting df about auction asta-alloggi-31-gennaio-2017
# Extracting df about auction asta-alloggi-06-luglio-2017
# Extracting df about auction asta-alloggi-10-novembre-2017
# Extracting df about auction asta-alloggi-01-febbraio-2018-2
# Extracting df about auction asta-alloggi-17-dicembre-2020
# Extracting df about auction asta-alloggi-25-maggio-2017
# Extracting df about auction 4209-2
# Extracting df about auction asta-alloggi-05-ottobre-2017
# WARNING url https://web.archive.org/web/20170905070730/http://www.alermipianovendite.it/asta-alloggi-05-ottobre-2017/ doesn't contains data

# %%
dfs_2 = extract_dataframe_from_webpage(complete_links_2)
# Out:
# Extracting df about auction 148-asta-ceal-mag-2016.html
# Extracting df about auction 154-esito-ceal-alloggi-giu-2016.html
# WARNING url https://web.archive.org/web/20160816163337/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/154-esito-ceal-alloggi-giu-2016.html doesn't contains data
# Extracting df about auction 118-esito-ceal-alloggi-lug-2015.html
# WARNING url https://web.archive.org/web/20150815081815/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/118-esito-ceal-alloggi-lug-2015.html doesn't contains data
# Extracting df about auction 87-asta-gennaio-2015.html
# Extracting df about auction 144-asta-ceal-apr-2016.html
# Error analyzing url https://web.archive.org/web/20160416233327/http://www.alermipianovendite.it/vendite/venditeasta/18-aste-alloggi/144-asta-ceal-apr-2016.html. Error HTTP Error 404: Article not found
# Extracting df about auction 108-asta-maggio-2015.html
# Extracting df about auction 100-asta-aprile-2015.html
# Extracting df about auction 112-asta-luglio-2015.html
# Extracting df about auction 134-esito-ceal-alloggi-dic-2015.html
# WARNING url https://web.archive.org/web/20151231231712/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/134-esito-ceal-alloggi-dic-2015.html doesn't contains data
# Extracting df about auction 140-asta-ceal-mar-2016.html
# Extracting df about auction 136-asta-ceal-feb-2016.html
# Extracting df about auction 120-asta-ottobre-2015.html
# Error analyzing url https://web.archive.org/web/20150915042032/http://www.alermipianovendite.it/vendite/venditeasta/18-aste-alloggi/120-asta-ottobre-2015.html. Error HTTP Error 404: NOT FOUND
# Extracting df about auction 122-asta-novembre-2015.html
# Extracting df about auction 156-asta-ceal-ott-2016.html
# Extracting df about auction 129-asta-dicembre-2015.html
# Extracting df about auction 152-asta-ceal-giu-2016.html
# Extracting df about auction 98-esito-ceal-alloggi-feb-2015.html
# WARNING url https://web.archive.org/web/20150411081628/http://www.alermipianovendite.it/vendite/venditeasta/21-aste-cela-chiuse/98-esito-ceal-alloggi-feb-2015.html doesn't contains data

# %%
columns_1 = ['LOTTO', 'UOG', 'LOCALITA', 'VIA', 'CIVICO', 'ID', 'LOCALI', 'MQ', 'ASCENSORE', 'CLASSE ENERGETICA', 'TIPOLOGIA', 'STATO GIURIDICO', 'PREZZO BASE ASTA']
columns_2 = ['LOTTO', 'UOG', 'LOCALITA', 'VIA', 'CIVICO', 'ID', 'LOCALI', 'ASCENSORE', 'CLASSE ENERGETICA', 'TIPOLOGIA', 'STATO GIURIDICO', 'PREZZO BASE ASTA', 'MQ']

df_1 = normalize_dfs(dfs_1,  columns_1)
df_2 = normalize_dfs(dfs_2,  columns_2)
df_2.rename({"DESTINAZIONE D'USO": 'TIPOLOGIA'}, inplace = True)

# %%
df_1.head(2)
# Out:
#     LOTTO   UOG LOCALITA                   VIA CIVICO   ID  LOCALI  MQ  \
# 0  077/18  UOG4   MILANO  VIA GIOVANNI PASCOLI     '4  NaN     2.0  46
# 1  078/18  UOG2   MILANO   VIA ERCOLE FERRARIO     '7  NaN     3.0  99
#
#   ASCENSORE CLASSE ENERGETICA TIPOLOGIA STATO GIURIDICO PREZZO BASE ASTA
# 0        NO                 G  ALLOGGIO     PIENA PROP.      € 62.928,00
# 1        SI                 F  ALLOGGIO     PIENA PROP.      €203.148,00

# %%
df_2.head(2)
# Out:
#     LOTTO UOG LOCALITA                      VIA CIVICO   ID  LOCALI ASCENSORE  \
# 0  167/16  NE   MILANO     VIA GIOVANNI PASCOLI      4  NaN       1        NO
# 1  168/16  SO   MILANO  VIA JACOPINO DA TRADATE      8    A       2        NO
#
#   CLASSE ENERGETICA TIPOLOGIA STATO GIURIDICO PREZZO BASE ASTA   MQ
# 0                 G  ALLOGGIO     PIENA PROP.      € 48.160,00  NaN
# 1                 G  ALLOGGIO     PIENA PROP.      € 37.440,00  NaN

# %%
cols = ['LOTTO', 'LOCALI', 'MQ', 'CLASSE ENERGETICA', 'TIPOLOGIA', 'STATO GIURIDICO']
data_joined1 = pd.merge(data2, df_1[cols], how="inner", on="LOTTO")
data_joined2 = pd.merge(data2, df_2[cols], how="inner", on="LOTTO")
result = pd.concat([data_joined1,data_joined2])

not_included_ids = set(data2['LOTTO'].unique()) - set(result['LOTTO'].unique())
not_included_df = data2[data2['LOTTO'].isin(not_included_ids)]

# %% [markdown]
# ## Final Data

# %%
print(not_included_df.shape)
not_included_df.head(3)
# Out:
# (1033, 16)
#     LOTTO  CODICE LOCALITA       INDIRIZZO CIVICO   ID  PREZZO BASE  \
# 0  252/15   20148   MILANO   VIA MAC MAHON    '89  NaN  € 93.139,00
# 1  112/16   20134   MILANO   VIA MAC MAHON    '89  NaN  € 75.840,00
# 6  253/15  230196   MILANO  VIA BRAMANTINO     '3  NaN  € 80.784,00
#
#       PREZZO_AG     AGGIUDICATARIO GIORNO     MESE ANNO BOX/P.A.  \
# 0  € 116.000,00  ROLLERI FRANCESCO     01  ottobre   15      NaN
# 1   € 79.150,00      NICOSIA PAOLO     21   aprile   16      NaN
# 6        € 0,00       ASTA DESERTA     01  ottobre   15      NaN
#
#                      address        lat       lng
# 0  VIA MAC MAHON '89, MILANO  45.494911  9.156308
# 1  VIA MAC MAHON '89, MILANO  45.494911  9.156308
# 6  VIA BRAMANTINO '3, MILANO  45.497144  9.152361

# %%
print(result.shape)
result.head(3)
# Out:
# (1203, 21)
#     LOTTO  CODICE LOCALITA                INDIRIZZO CIVICO   ID  PREZZO BASE  \
# 0  038/18  230617   MILANO  VIA JACOPINO DA TRADATE    '14  NaN  € 68.160,00
# 1  146/17  230636   MILANO  VIA JACOPINO DA TRADATE    '14  NaN  € 36.480,00
# 2  241/17  230588   MILANO  VIA JACOPINO DA TRADATE    '14  NaN  € 62.220,00
#
#       PREZZO_AG        AGGIUDICATARIO GIORNO  ... ANNO BOX/P.A.  \
# 0  € 102.000,00  BISSOLOTTI FRANCESCO     12  ...   18      NaN
# 1   € 47.500,00     GIAMPAOLO ROSARIA     06  ...   17      NaN
# 2   € 91.110,00          PAVIN ANDREA     10  ...   17      NaN
#
#                                address        lat       lng  LOCALI  MQ  \
# 0  VIA JACOPINO DA TRADATE '14, MILANO  45.495774  9.151054     3.0  71
# 1  VIA JACOPINO DA TRADATE '14, MILANO  45.495774  9.151054     2.0  38
# 2  VIA JACOPINO DA TRADATE '14, MILANO  45.495774  9.151054     3.0  61
#
#   CLASSE ENERGETICA TIPOLOGIA STATO GIURIDICO
# 0                 G  ALLOGGIO     PIENA PROP.
# 1                 G  ALLOGGIO     PIENA PROP.
# 2                 G  ALLOGGIO     PIENA PROP.
#
# [3 rows x 21 columns]

# %%
result.to_csv("./final_data.csv")
not_included_df.to_csv("./final_data.csv")
# Out:
# array(['15', '16', '19', '18', '17', '2020', '2021'], dtype=object)
