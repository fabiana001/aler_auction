# %%
from aler_auctions.wayback_client import Snapshot, WaybackClient
from pathlib import Path

# %%
output_dir = "./alermipianovendite_aste_webarchive"
url = "alermipianovendite.it/asta-alloggi/"

client = WaybackClient()

# %%
snapshots = client.search_snapshots(url)

# %%
list_paths = client.fetch_pages(snapshots, output_dir)

# %%
tag_name = "article",
class_value = "category-asteceal"

list_html = client.parse_html_pages(output_dir, tag_name, class_value, remove_duplicates=True)
len(list_html)
# Out:
# Ignored links: ['https://web.archive.org/web/20200924044539/https://alermipianovendite.it/asta-alloggi-24-settembre-2020/']
# 28

# %%
sorted(list_html, reverse=True)
# Out:
# ['https://web.archive.org/web/20251114050448/https://alermipianovendite.it/asta-alloggi-27-novembre-2025/',
#  'https://web.archive.org/web/20250719044336/https://alermipianovendite.it/asta-alloggi-9-settembre-2025/',
#  'https://web.archive.org/web/20250513123226/https://alermipianovendite.it/asta-alloggi-12-giugno-2025/',
#  'https://web.archive.org/web/20250320140526/https://alermipianovendite.it/asta-alloggi-3-aprile-2025/',
#  'https://web.archive.org/web/20250120213216/https://alermipianovendite.it/asta-alloggi-13-febbraio-2025/',
#  'https://web.archive.org/web/20240913210249/https://alermipianovendite.it/asta-alloggi-19-settembre-2024/',
#  'https://web.archive.org/web/20231018103038/https://alermipianovendite.it/asta-alloggi-23-novembre-2023/',
#  'https://web.archive.org/web/20220703171612/https://alermipianovendite.it/asta-alloggi-14-luglio-2022/',
#  'https://web.archive.org/web/20210921043228/https://alermipianovendite.it/asta-alloggi-23-settembre-2021/',
# ...
